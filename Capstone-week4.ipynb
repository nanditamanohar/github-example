# %%
from PIL import Image
import requests
url = 'https://www.frisco.com/photos/images/db/147973_TownHall.jpg'
im = Image.open(requests.get(url, stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x795 at 0x13DE7380320>

# %% [markdown]
# # Introduction
#
# Frisco city housing market is growing rapidly,  ABC builder is planning to build a 4 brand new housing community at different price points and different housing styles( condos, townhomes, single family and luxury collection). As the city grows and develops, it becomes increasingly important to examine and understand it quantitatively.

# %% [markdown]
# # Questions
#
# How the economic data affect the type of home and price point built?
#
# How the health data affect the type of home and price point built?
#
# How the demographic data affect the type of home and price point built?
#
# How the education data affect the type of home and price point built?
#
# How the housing data affect the type of home and price point built?
#
# Using Foursquare data, what venues are most common in different locations within the city for different housing segments?

# %% [markdown]
# # Data
# To understand and explore we will need the following City of Frisco Open Data:
#
# 1.Frisco city data: http://www.city-data.com/city/Frisco-Texas.html
#
# 2.Frisco economy data: https://datausa.io/profile/geo/frisco-tx/#economy
#
# 3.Frisco health data: https://datausa.io/profile/geo/frisco-tx/#health
#
# 4.Frisco demographics data: https://datausa.io/profile/geo/frisco-tx/#demographics
#
# 5.Frisco education data: https://datausa.io/profile/geo/frisco-tx/#education
#
# 6.Frisco housing data: https://datausa.io/profile/geo/frisco-tx/#housing
#
# 7.Foursquare Developers Access to venue data: https://foursquare.com/
